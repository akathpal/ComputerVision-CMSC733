# %%
try:
    sys.path.remove('/opt/ros/kinetic/lib/python2.7/dist-packages')
except:
    pass

import cv2
import dlib
import numpy as np
import imutils
from imutils import face_utils
import matplotlib.pyplot as plt

# %%
#initialize facial detector
# detector = dlib.get_frontal_face_detector()
# predictor = dlib.shape_predictor('/home/abhinav/CMSC-733/Abhi1625_p2/shape_predictor.dat')

# %%
# gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
# gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
# img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
# img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# img1 = imutils.resize(gray1,width = 600, height = 600)
# img2 = imutils.resize(gray2,width = 600, height = 600)

# %%
def features(img):
    #initialize facial detector
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray,(600,600))
    img = cv2.resize(img,(600,600))
    
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor('/home/abhinav/CMSC-733/Abhi1625_p2/shape_predictor.dat')
    rects = detector(gray,1)
    
    
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    for (i,rect) in enumerate(rects):
        
        shape = predictor(gray,rect)
        shape = face_utils.shape_to_np(shape)


        (x,y,w,h) = face_utils.rect_to_bb(rect)
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)


        for (x,y) in shape:
            cv2.circle(img,(x,y),2,(0,0,255),-1)
    return img

# %%
img1 = cv2.imread('yiannis.jpeg')
img2 = cv2.imread('chetan.jpg')

img1 = features(img1)
img2 = features(img2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-d0ab382a5b82> in <module>()
#       2 img2 = cv2.imread('chetan.jpg')
#       3
# ----> 4 img1 = features(img1)
#       5 img2 = features(img2)
#
# <ipython-input-2-e29fc288b038> in features(img)
#       6
#       7     detector = dlib.get_frontal_face_detector()
# ----> 8     predictor = dlib.shape_predictor('/home/abhinav/CMSC-733/Abhi1625_p2/shape_predictor.dat')
#       9     rects = detector(gray,1)
#      10
#
# RuntimeError: Unable to open /home/abhinav/CMSC-733/Abhi1625_p2/shape_predictor.dat

# %%
plt.rcParams["figure.figsize"] = (10,10)
plt.imshow(img1)

# %%
plt.rcParams["figure.figsize"] = (10,10)
plt.imshow(img2)
